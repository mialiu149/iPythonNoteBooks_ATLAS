# %%
# %pylab inline
#Function for reading slopes from ps files
# lists to store slopes for different parts of the detector
EAAMu = [2.988e-05,3.55e-05,4.549e-05,4.034e-05,3.636e-05,4.713e-05,4.376e-05,3.728e-05,4.264e-05]
EAAMuerror = [8.638e-06,3.64e-06,6.429e-06, 4.298e-06,4.993e-06,6.914e-06,6.424e-06,7.698e-06,4.884e-06]
EAA = [1.513e-05,2.803e-05,3.937e-05,3.289e-05,3.972e-05,4.211e-05,4.022e-05,3.301e-05,3.903e-05]
EAAerror = [6.024e-06, 2.526e-06,4.470e-06,2.975e-06,3.450e-06,4.769e-06,4.420e-06,5.285e-06,3.362e-06]
ECAMu = [1.494e-05,1.951e-05,2.357e-05,3.21e-05,3.088e-05,2.209e-05,5.184e-05,3.871e-05,3.842e-05]
ECAMuerror = [8.443e-06,3.578e-06,6.382e-06,4.27e-06,4.983e-06,6.895e-06,6.530e-06,7.783e-06,4.903e-06]
ECA = [2.202e-05,1.824e-05,2.271e-05,2.661e-05,2.481e-05,2.202e-05,3.814e-05,3.733e-05,3.371e-05]
ECAerror = [5.904e-06,2.488e-06,4.442e-06,2.961e-06,3.442e-06,4.757e-06,4.514e-06,5.358e-06,3.383e-06]
#x = linspace(0.5,len(EAAMu)-0.5,len(EAAMu))
location='/Users/Mia/Documents/TRTAging/'
Periods=['A', 'B', 'C', 'D', 'E','G','H','I','J']
# plot slopes as a function of integrated luminosity
x = [0.84,6.14,7.58,10.99,13.6,14.9,16.47,17.526,19.16]
ind = arange(len(EAAMu))-0.5
print ind
width = 2

errorbar(x,EAA,yerr=EAAerror,fmt='-o',label='EndCap A')
#errorbar(x,EAAMu,yerr=EAAMuerror,fmt='--o',label='EndCap A, muon')
errorbar(x,ECA,yerr=ECAerror,fmt='-o',label='EndCap C')
#errorbar(x,ECAMu,yerr=ECAMuerror,fmt='--o',label='EndCap C, muon')
legend(loc=0,bbox_to_anchor = (0.3, 0.7),fontsize=8)
#xticks(ind+width/2, ('PeriodA', 'PeriodB', 'PeriodC', 'PeriodD', 'PeriodE','PeriodG','PeriodH') )
#xticks(x, ('A', 'B', 'C', 'D', 'E','G','H','I','J') )
xlabel('Integrated luminosity in 2012 [$fb^{-1}$]')
#relim()
locs,labels = yticks()
yticks(locs, map(lambda EAA: "%.1f" % EAA, locs*1e5))
title('Slopes for data 2012, Wheel Type A')
ylabel('Slopes(10e-5/mm)')
savefig('/Users/Mia/Documents/Thesis/DissertationMia/Chapter3/trunk/figures_pdf/SlopeChangeData12WheelTypeA.pdf')
#annotate('annotate', xy=(2, 1), xytext=(3, 4),arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [-0.5  0.5  1.5  2.5  3.5  4.5  5.5  6.5  7.5]

# %%
EABMu=[-7.39e-05,-0.0001065,-0.0001195,-0.0001198, -0.0001197,-0.0001297 ,-0.0001238,-0.0001278,-0.0001293]
EABMuerror=[1.24e-05, 0.0000053,0.0000094,0.0000062,0.0000072,0.0000100,0.0000093,0.0000112,0.0000071]
EAB=[-5.951e-05,-8.781e-05,-9.278e-05,-9.683e-05,-9.526e-05,-0.0001064,-9.3e-05,-0.0001035,-0.0001077]
EABerror=[ 9.547e-06,4.057e-06,7.176e-06,4.758e-06,5.505e-06,0.0000076, 7.1e-06,0.0000084,0.0000054]
ECBMu=[-6.076e-05,-9.75e-05,-0.0001055,-0.0001031,-0.0001114,-0.0001105,-9.731e-05,-0.0001107,-0.0001147]
ECBMuerror=[1.236e-05,5.30e-06,0.0000094,0.0000062,0.0000072,0.0000100,9.327e-06,0.0000112,0.0000071]
ECB=[-5.141e-05,-7.33e-05,-8.526e-05,-7.81e-05,-8.033e-05,-8.598e-05,-7.514e-05,-8.325e-05,-8.191e-05]
ECBerror=[9.487e-06,4.03e-06,7.151e-06,4.74e-06,5.494e-06,7.600e-06,7.056e-06, 8.415e-06,5.346e-06]
#x = linspace(0.5,len(EAAMu)-0.5,len(EAAMu))
ind = arange(len(EAAMu))-0.5
print ind
width = 2
#plot(x,EAAMu)
#plot(x,EAA)
#plot(x,ECAMu)
#plot(x,ECA)
#text(0.95, 0.01, 'PeriodA',verticalalignment='bottom', horizontalalignment='right',color='green', fontsize=15)
errorbar(x,EAB,yerr=EABerror,fmt='-o',label='EndCap A')
#errorbar(x,EABMu,yerr=EABMuerror,fmt='--o',label='EndCap A, muon')
errorbar(x,ECB,yerr=ECBerror,fmt='-o',label='EndCap C')
#errorbar(x,ECBMu,yerr=ECBMuerror,fmt='--o',label='EndCap C, muon')
legend(loc=0,bbox_to_anchor = (0.3, 0.7),fontsize=8)
#xticks(x, ('A', 'B', 'C', 'D', 'E','G','H','I','J') )
#relim()
locs,labels = yticks()
yticks(locs, map(lambda EAB: "%.1f" % EAB, locs*1e5))
title('Slopes for data 2012, Wheel Type B')
ylabel('Slopes(10e-5/mm)')
xlabel('Integrated luminosity in 2012 [$fb^{-1}$]')
savefig('/Users/Mia/Documents/Thesis/DissertationMia/Chapter3/trunk/figures_pdf/SlopeChangeData12WheelTypeB.pdf')
#annotate('annotate', xy=(2, 1), xytext=(3, 4),arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# [-0.5  0.5  1.5  2.5  3.5  4.5  5.5  6.5  7.5]

# %%
B1MuA=[-3.674e-05,4.753e-05,4.059e-05,1.706e-05,4.349e-05,-1.371e-05,5.218e-05,6.191e-06,5.322e-05]
B1MuC=[6.75e-05,9.956e-05,0.0001467,9.67e-05,9.438e-05,5.775e-05,9.11e-05,7.084e-05,8.314e-05]
B1MuL=[1.568e-05,3.45e-05,3.39e-05,3.63e-05,3.631e-05,3.707e-05,3.773e-05,3.881e-05,3.868e-05]
B1MuAError=[3.346e-05,1.395e-05,2.440e-05,1.637e-05,1.919e-05,2.607e-05,2.427e-05,1.859e-05,1.820e-05]
B1MuCError=[3.31e-05,1.345e-05,0.0000236,1.57e-05,1.845e-05,2.511e-05,2.36e-05,1.816e-05,1.777e-05]
B1MuLError=[3.460e-06,1.43e-06,2.53e-06,1.68e-06,1.955e-06,2.656e-06,2.488e-06,1.878e-06,1.870e-06]
B1L=[2.058e-05,3.24e-05,3.13e-05,3.417e-05,3.479e-05,3.462e-05,3.641e-05,3.881e-05,3.545e-05]
B1A=[-2.314e-05,3.487e-05,4.151e-05,3.332e-05,4.938e-05,-1.273e-06,7.924e-05,1.878e-06,1.201e-06]
B1C=[7.548e-05,8.136e-05,0.0001233,8.661e-05,8.958e-05,7.466e-05,6.228e-05,7.084e-05,7.1e-05]
B1AError=[2.171e-05,9.068e-06,1.599e-05,1.061e-05,1.237e-05,1.686e-05,1.571e-05,1.859e-05,1.177e-05]
B1CError=[2.146e-05,8.842e-06,0.0000155,1.031e-05,1.205e-05,1.643e-05,1.535e-05,1.816e-05,1.2e-05]
B1LError=[2.229e-06,9.26e-07,1.65e-06,1.085e-06,1.258e-06,1.715e-06,1.598e-06,1.285e-06,1.878e-06]
#x = linspace(0.5,len(B1MuL)-0.5,len(B1MuL))
ind = arange(len(EAAMu))-0.5
print ind
width = 2
errorbar(x,B1A,yerr=B1AError,fmt='-o',label='short straw,SideA')
#errorbar(x,B1MuA,yerr=B1MuAError,fmt='--o',label='short straw,SideA,Muon')
errorbar(x,B1C,yerr=B1CError,fmt='-o',label='short straw,SideC')
#errorbar(x,B1MuC,yerr=B1MuCError,fmt='--o',label='short straw,SideC,Muon')
legend(loc=0,bbox_to_anchor = (0.4, 0.3),fontsize=7.5)
#xticks(x, ('A', 'B', 'C', 'D', 'E','G','H','I','J') )
locs,labels = yticks()
yticks(locs, map(lambda EAB: "%.1f" % EAB, locs*1e5))
title('Slopes for data 2012, Barrel Layer 0')
ylabel('Slopes(10e-5/mm)')
xlabel('Integrated Luminosity in 2012 [$fb^{-1}$]')
savefig('/Users/Mia/Documents/Thesis/DissertationMia/Chapter3/trunk/figures_pdf/SlopeChangeData12Barrel0.pdf')
# Out:
# [-0.5  0.5  1.5  2.5  3.5  4.5  5.5  6.5  7.5]

# %%
B2=[1.366e-05,1.967e-05,2.326e-05,2.639e-05,2.85e-05,2.702e-05,2.842e-05,2.926e-05,2.761e-05]
B2Error=[1.520e-06,6.272e-07,1.114e-06,7.360e-07,8.47e-07,1.168e-06,1.082e-06,1.285e-06,8.219e-07]
B2pileup=[1.026e-05,1.661e-05,2.107e-05,2.684e-05,2.412e-05,2.652e-05,3.263e-05,2.604e-05,1.987e-05 ]
B2pileupError=[3.891e-06,1.983e-06,3.108e-06,2.321e-06,2.928e-06,3.967e-06,4.236e-06,5.875e-06,2.784e-06]
B3=[5.403e-06,1.16e-05,1.313e-05,1.533e-05,1.549e-05,1.293e-05,1.444e-05,1.557e-05,1.655e-05]
B3Error=[1.567e-06,6.39e-07,1.126e-06,7.473e-07,8.630e-07,1.190e-06,1.105e-06,1.317e-06,8.404e-07]
B2Mu=[1.382e-05,2.032e-05,2.36e-05,2.663e-05,2.945e-05,3.174e-05,2.994e-05,2.926e-05,2.761e-05]
B2MuError=[2.376e-06,9.727e-07,1.71e-06,1.142e-06,1.322e-06,1.818e-06,1.689e-06,1.285e-06,8.219e-07]
B3Mu=[6.891e-06,1.153e-05,1.555e-05,1.699e-05,1.629e-05,1.714e-05,1.597e-05,1.557e-05,1.822e-05]
B3MuError=[2.422e-06,9.766e-07,1.709e-06,1.142e-06,1.326e-06,1.821e-06,1.699e-06,1.317e-06,1.292e-06]
#x = linspace(0.5,len(B2Mu)-0.5,len(B2Mu))
ind = np.arange(len(B2Mu))-0.5
print ind
width = 2
errorbar(x,B1L,yerr=B1LError,fmt='-o',label='Layer1 long straw')
#errorbar(x,B1MuL,yerr=B1MuLError,fmt='--o',label='Layer 1 long straw,Muon')
errorbar(x,B2,yerr=B2Error,fmt='-o',label='Layer2')
errorbar(x,B2pileup,yerr=B2pileupError,fmt='-v',label='Barrel L1,$\mu$[14,16]')
#errorbar(x,B2Mu,yerr=B2MuError,fmt='--o',label='Barrel L1,Muon')
errorbar(x,B3,yerr=B3Error,fmt='-o',label='Layer3')
#errorbar(x,B3Mu,yerr=B3MuError,fmt='--o',label='Barrel L2,Muon')
legend(loc=0,bbox_to_anchor = (0.35, 0.72),fontsize=8)
#xticks(ind+width/2, ('PeriodA', 'PeriodB', 'PeriodC', 'PeriodD', 'PeriodE','PeriodG','PeriodH') )
#xticks(x, ('A', 'B', 'C', 'D', 'E','G','H','I','J') )
#relim()
locs,labels = yticks()
yticks(locs, map(lambda EAB: "%.1f" % EAB, locs*1e5))
title('Slopes for data 12, Barrel')
ylabel('Slopes(10e-5/mm)')
xlabel('Integrated Luminosity in 2012 [$fb^{-1}$]')
savefig('/Users/Mia/Documents/Thesis/DissertationMia/Chapter3/trunk/figures_pdf/SlopeChangeData12Barrel_ForBen.pdf')
# Out:
# [-0.5  0.5  1.5  2.5  3.5  4.5  5.5  6.5  7.5]
